# %% [markdown]
# # 📈 Visualize Stock Prices with Plotly

# %%
# %pip install plotly pandas
# Out:
# Requirement already satisfied: plotly in /Users/amantanna/Downloads/ML_Project/venv/lib/python3.11/site-packages (6.2.0)
# Requirement already satisfied: pandas in /Users/amantanna/Downloads/ML_Project/venv/lib/python3.11/site-packages (2.3.1)
# Requirement already satisfied: narwhals>=1.15.1 in /Users/amantanna/Downloads/ML_Project/venv/lib/python3.11/site-packages (from plotly) (1.48.1)
# Requirement already satisfied: packaging in /Users/amantanna/Downloads/ML_Project/venv/lib/python3.11/site-packages (from plotly) (25.0)
# Requirement already satisfied: numpy>=1.23.2 in /Users/amantanna/Downloads/ML_Project/venv/lib/python3.11/site-packages (from pandas) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/amantanna/Downloads/ML_Project/venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/amantanna/Downloads/ML_Project/venv/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/amantanna/Downloads/ML_Project/venv/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/amantanna/Downloads/ML_Project/venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# ## 🔄 Load and Preview Your Data

# %%
df = pd.read_csv('stocks_data.csv', parse_dates=['date'])
df.head()
# Out:
#         date symbol       open       high        low      close   volume  \
# 0 2020-01-02      A  85.900002  86.349998  85.199997  85.949997  1410500
# 1 2020-01-03      A  84.669998  85.330002  84.500000  84.570000  1118300
# 2 2020-01-06      A  84.000000  84.820000  83.599998  84.820000  1993200
# 3 2020-01-07      A  83.959999  85.260002  83.940002  85.080002  1684700
# 4 2020-01-08      A  85.959999  86.470001  85.199997  85.919998  1847600
#
#    dividends  stock_splits  capital_gains       sector
# 0        0.0           0.0            0.0  Health Care
# 1        0.0           0.0            0.0  Health Care
# 2        0.0           0.0            0.0  Health Care
# 3        0.0           0.0            0.0  Health Care
# 4        0.0           0.0            0.0  Health Care

# %% [markdown]
# ## 📉 Line Chart for a Single Stock

# %%
aapl_df = df[df['symbol'] == 'AAPL']
fig = px.line(aapl_df, x='date', y='close', title='AAPL Stock Price Over Time')
fig.show()

# %% [markdown]
# ## 📊 Compare Multiple Tickers

# %%
tickers = ['AAPL', 'MSFT', 'GOOGL']
subset = df[df['symbol'].isin(tickers)]
fig = px.line(subset, x='date', y='close', color='symbol', title='Stock Price Comparison')
fig.show()

# %% [markdown]
# ## 🖱️ Enhanced Hover Information

# %%
fig = px.line(
    aapl_df, x='date', y='close', title='AAPL Stock Price with Hover Info',
    hover_data={'symbol': True, 'close': ':.2f'}
)
fig.show()

# %% [markdown]
# ## 💾 Save Chart as HTML

# %%
fig.write_html('aapl_stock_chart.html')
